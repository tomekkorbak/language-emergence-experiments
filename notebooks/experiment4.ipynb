# %% [markdown]
# # Experiment 4

# %%
import random

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.distributions import Categorical
from torch.optim import Adam
import seaborn as sns

random.seed(44)
torch.manual_seed(1773)
sns.set(rc={'figure.figsize':(15,20)})

# %%
class SpeakerNet(nn.Module):
    def __init__(self, input_size, alphabet_size):
        super().__init__()
        self.linear = nn.Embedding(input_size, alphabet_size)

    def forward(self, input):
        return F.softmax(self.linear(input), dim=1)
    
class ListenerNet(nn.Module):
    def __init__(self, alphabet_size, output_size):
        super().__init__()
        self.linear = nn.Embedding(alphabet_size, output_size)

    def forward(self, input):
        return F.softmax(self.linear(input), dim=1)

# %%
class Agent:
    def __init__(self, id, world_size, alphabet_size, learning_rate=0.1):
        self.id = id
        self.speak = SpeakerNet(world_size, alphabet_size)
        self.listen = ListenerNet(alphabet_size, world_size)
        self.speak_optimizer = Adam(params=self.speak.parameters(), lr=learning_rate)
        self.listen_optimizer = Adam(params=self.listen.parameters(), lr=learning_rate)
        
    def observe_and_speak(self, observation):
        probs = self.speak(observation)
        distribution = Categorical(probs)
        message = distribution.sample()
        self.last_message_probs, self.last_message = distribution.log_prob(message), message
        return message
    
    def get_reward_for_speaking(self, rewards):
        self.speak_optimizer.zero_grad()  
        loss = -(self.last_message_probs * rewards).sum()
        loss.backward()
        self.speak_optimizer.step()
        return loss
    
    def listen_and_predict(self, message):
        self.received_message = message
        return self.listen(message)
    
    def get_reward_for_listening(self, loss):
        self.listen_optimizer.zero_grad()  
        loss.backward()
        self.listen_optimizer.step()
        return self.listen.linear.weight.grad

# %%
class DifferentiableWorld:
    def __init__(self, batch_size, world_size):
        self.batch_size, self.world_size = batch_size, world_size
        self.reset()
    
    def reset(self):
        self.hidden_state = torch.randint(
            high=self.world_size, 
            size=(self.batch_size,),
            dtype=torch.long
        )
    
    def receive_observation(self):
        return self.hidden_state
    
    def evaluate_prediction(self, pred):
        return F.nll_loss(pred, self.hidden_state)

# %%
def train(population_size=1):
    population = [Agent(id=i, world_size=10, alphabet_size=15, learning_rate=1) for i in range(population_size)]
    world = DifferentiableWorld(batch_size=16, world_size=10)
    for epoch in range(1_000_000):
        # Choose two agents (with replacement, with order) for each epoch
        sender, receiver = random.choices(population, k=2)
        observation = world.receive_observation()
        message = sender.observe_and_speak(observation)
        prediction = receiver.listen_and_predict(message)
        receiver_loss = world.evaluate_prediction(prediction)
        rewards_for_sender = receiver.get_reward_for_listening(receiver_loss)
        speaker_loss = sender.get_reward_for_speaking(rewards_for_sender[message].sum(dim=1))
        world.reset()
        if epoch % 10000 == 0:
            print(f'Epoch {epoch}, agent {sender.id} talking to agent {receiver.id}')
            print(f'Speaker loss: {speaker_loss:.2f}, receiver loss: {receiver_loss:.2f}')
            print(observation[:5], message[:5], prediction.argmax(dim=1)[:5])

# %%
train(3)
# Out:
# Epoch 0, agent 2 talking to agent 0
# Speaker loss: -0.00, receiver loss: -0.09
# tensor([1, 1, 4, 4, 4]) tensor([10,  8,  4, 10,  5]) tensor([0, 3, 9, 0, 5])
# Epoch 10000, agent 2 talking to agent 1
# Speaker loss: 0.00, receiver loss: -0.56
# tensor([5, 0, 5, 9, 3]) tensor([8, 2, 8, 2, 4]) tensor([5, 2, 5, 2, 3])
# Epoch 20000, agent 0 talking to agent 2
# Speaker loss: -0.00, receiver loss: -0.25
# tensor([0, 1, 7, 3, 4]) tensor([9, 9, 9, 4, 9]) tensor([1, 1, 1, 3, 1])
# Epoch 30000, agent 0 talking to agent 2
# Speaker loss: 0.00, receiver loss: -0.12
# tensor([6, 9, 5, 8, 9]) tensor([9, 9, 9, 9, 9]) tensor([1, 1, 1, 1, 1])
# Epoch 40000, agent 1 talking to agent 0
# Speaker loss: 0.00, receiver loss: -0.19
# tensor([2, 2, 9, 8, 1]) tensor([2, 2, 2, 0, 0]) tensor([2, 2, 2, 1, 1])
# Epoch 50000, agent 2 talking to agent 0
# Speaker loss: 0.00, receiver loss: -0.50
# tensor([7, 9, 8, 0, 1]) tensor([2, 2, 2, 2, 0]) tensor([2, 2, 2, 2, 1])
# Epoch 60000, agent 1 talking to agent 0
# Speaker loss: 0.00, receiver loss: -0.12
# tensor([9, 4, 8, 9, 0]) tensor([2, 2, 0, 2, 0]) tensor([2, 2, 1, 2, 1])
# Epoch 70000, agent 2 talking to agent 2
# Speaker loss: 0.00, receiver loss: -0.38
# tensor([9, 1, 0, 3, 0]) tensor([2, 0, 2, 4, 2]) tensor([2, 1, 2, 3, 2])
# Epoch 80000, agent 0 talking to agent 2
# Speaker loss: 0.00, receiver loss: -0.31
# tensor([0, 0, 3, 0, 6]) tensor([9, 9, 4, 9, 9]) tensor([1, 1, 3, 1, 1])
# Epoch 90000, agent 1 talking to agent 0
# Speaker loss: 0.00, receiver loss: -0.38
# tensor([5, 7, 1, 4, 8]) tensor([2, 0, 0, 2, 0]) tensor([2, 1, 1, 2, 1])
# Epoch 100000, agent 2 talking to agent 1
# Speaker loss: 0.00, receiver loss: -0.69
# tensor([8, 6, 3, 4, 1]) tensor([11,  2,  4,  0,  0]) tensor([8, 6, 3, 1, 1])
# Epoch 110000, agent 1 talking to agent 0
# Speaker loss: 0.00, receiver loss: -0.06
# tensor([7, 4, 7, 9, 8]) tensor([0, 2, 0, 2, 0]) tensor([1, 2, 1, 2, 1])
# Epoch 120000, agent 0 talking to agent 1
# Speaker loss: 0.00, receiver loss: -0.06
# tensor([5, 0, 0, 8, 8]) tensor([9, 9, 9, 9, 9]) tensor([1, 1, 1, 1, 1])
# Epoch 130000, agent 0 talking to agent 1
# Speaker loss: 0.00, receiver loss: -0.38
# tensor([3, 7, 8, 0, 7]) tensor([4, 9, 9, 9, 9]) tensor([3, 1, 1, 1, 1])
# Epoch 140000, agent 1 talking to agent 0
# Speaker loss: 0.00, receiver loss: -0.38
# tensor([3, 6, 0, 0, 1]) tensor([0, 3, 0, 0, 0]) tensor([1, 6, 1, 1, 1])
# Epoch 150000, agent 1 talking to agent 0
# Speaker loss: 0.00, receiver loss: -0.31
# tensor([2, 0, 4, 9, 2]) tensor([2, 0, 2, 2, 2]) tensor([2, 1, 2, 2, 2])
# Epoch 160000, agent 0 talking to agent 0
# Speaker loss: 0.00, receiver loss: -0.06
# tensor([2, 6, 8, 5, 1]) tensor([9, 9, 9, 9, 9]) tensor([7, 7, 7, 7, 7])
# Epoch 170000, agent 0 talking to agent 2
# Speaker loss: 0.00, receiver loss: -0.12
# tensor([2, 8, 1, 7, 6]) tensor([9, 9, 9, 9, 9]) tensor([1, 1, 1, 1, 1])
# Epoch 180000, agent 0 talking to agent 0
# Speaker loss: 0.00, receiver loss: -0.31
# tensor([3, 3, 9, 5, 5]) tensor([4, 4, 9, 9, 9]) tensor([3, 3, 7, 7, 7])
# Epoch 190000, agent 1 talking to agent 2
# Speaker loss: 0.00, receiver loss: -0.31
# tensor([3, 1, 8, 8, 8]) tensor([0, 0, 0, 0, 0]) tensor([1, 1, 1, 1, 1])
# Epoch 200000, agent 0 talking to agent 2
# Speaker loss: 0.00, receiver loss: -0.19
# tensor([3, 4, 9, 8, 9]) tensor([4, 9, 9, 9, 9]) tensor([3, 1, 1, 1, 1])
# Epoch 210000, agent 1 talking to agent 2
# Speaker loss: 0.00, receiver loss: -0.38
# tensor([1, 4, 8, 5, 2]) tensor([0, 2, 0, 2, 2]) tensor([1, 2, 1, 2, 2])
# Epoch 220000, agent 0 talking to agent 1
# Speaker loss: 0.00, receiver loss: -0.12
# tensor([3, 6, 8, 0, 8]) tensor([4, 9, 9, 9, 9]) tensor([3, 1, 1, 1, 1])
# Epoch 230000, agent 2 talking to agent 0
# Speaker loss: 0.00, receiver loss: -0.50
# tensor([4, 1, 9, 0, 9]) tensor([0, 0, 2, 2, 2]) tensor([1, 1, 2, 2, 2])
# Epoch 240000, agent 1 talking to agent 1
# Speaker loss: 0.00, receiver loss: -0.38
# tensor([2, 6, 8, 6, 8]) tensor([2, 3, 0, 3, 0]) tensor([6, 6, 1, 6, 1])
# Epoch 250000, agent 2 talking to agent 2
# Speaker loss: 0.00, receiver loss: -0.56
# tensor([8, 5, 1, 0, 4]) tensor([12,  8,  0,  2,  0]) tensor([8, 5, 1, 2, 1])
# Epoch 260000, agent 0 talking to agent 0
# Speaker loss: 0.00, receiver loss: -0.06
# tensor([0, 7, 8, 4, 0]) tensor([9, 9, 9, 9, 9]) tensor([7, 7, 7, 7, 7])
# Epoch 270000, agent 2 talking to agent 0
# Speaker loss: 0.00, receiver loss: -0.44
# tensor([8, 8, 9, 2, 9]) tensor([12, 12,  2,  2,  2]) tensor([8, 8, 2, 2, 2])
# Epoch 280000, agent 1 talking to agent 2
# Speaker loss: 0.00, receiver loss: -0.44
# tensor([5, 1, 0, 1, 0]) tensor([2, 0, 0, 0, 0]) tensor([2, 1, 1, 1, 1])
# Epoch 290000, agent 0 talking to agent 1
# Speaker loss: 0.00, receiver loss: -0.25
# tensor([1, 5, 3, 4, 7]) tensor([9, 9, 4, 9, 9]) tensor([1, 1, 3, 1, 1])
# Epoch 300000, agent 0 talking to agent 2
# Speaker loss: 0.00, receiver loss: -0.06
# tensor([8, 4, 0, 6, 6]) tensor([9, 9, 9, 9, 9]) tensor([1, 1, 1, 1, 1])
# Epoch 310000, agent 1 talking to agent 0
# Speaker loss: 0.00, receiver loss: -0.44
# tensor([6, 3, 1, 2, 9]) tensor([3, 0, 0, 2, 2]) tensor([6, 1, 1, 2, 2])
# Epoch 320000, agent 0 talking to agent 1
# Speaker loss: 0.00, receiver loss: -0.31
# tensor([1, 1, 6, 7, 6]) tensor([9, 9, 9, 9, 9]) tensor([1, 1, 1, 1, 1])
# Epoch 330000, agent 0 talking to agent 2
# Speaker loss: 0.00, receiver loss: -0.31
# tensor([3, 1, 6, 2, 5]) tensor([4, 9, 9, 9, 9]) tensor([3, 1, 1, 1, 1])
# Epoch 340000, agent 2 talking to agent 2
# Speaker loss: 0.00, receiver loss: -0.44
# tensor([4, 3, 8, 3, 8]) tensor([0, 4, 6, 4, 6]) tensor([1, 3, 9, 3, 9])
# Epoch 350000, agent 1 talking to agent 1
# Speaker loss: 0.00, receiver loss: -0.12
# tensor([9, 0, 8, 5, 5]) tensor([2, 0, 0, 2, 2]) tensor([6, 1, 1, 6, 6])
# Epoch 360000, agent 2 talking to agent 1
# Speaker loss: 0.00, receiver loss: -0.50
# tensor([1, 5, 6, 9, 7]) tensor([0, 8, 2, 2, 2]) tensor([1, 5, 6, 6, 6])
# Epoch 370000, agent 1 talking to agent 1
# Speaker loss: 0.00, receiver loss: -0.12
# tensor([9, 9, 7, 4, 9]) tensor([2, 2, 0, 2, 2]) tensor([6, 6, 1, 6, 6])
# Epoch 380000, agent 1 talking to agent 2
# Speaker loss: 0.00, receiver loss: -0.19
# tensor([0, 2, 2, 4, 9]) tensor([0, 2, 2, 2, 2]) tensor([1, 2, 2, 2, 2])
# Epoch 390000, agent 1 talking to agent 1
# Speaker loss: 0.00, receiver loss: -0.06
# tensor([6, 4, 2, 8, 5]) tensor([7, 2, 2, 0, 2]) tensor([8, 6, 6, 1, 6])
# Epoch 400000, agent 2 talking to agent 2
# Speaker loss: 0.00, receiver loss: -0.44
# tensor([4, 5, 1, 0, 0]) tensor([0, 8, 0, 2, 2]) tensor([1, 5, 1, 2, 2])
# Epoch 410000, agent 0 talking to agent 1
# Speaker loss: 0.00, receiver loss: -0.19
# tensor([2, 1, 4, 3, 5]) tensor([9, 9, 9, 4, 9]) tensor([1, 1, 1, 3, 1])
# Epoch 420000, agent 0 talking to agent 0
# Speaker loss: 0.00, receiver loss: -0.12
# tensor([5, 8, 8, 8, 0]) tensor([9, 9, 9, 9, 9]) tensor([7, 7, 7, 7, 7])
# Epoch 430000, agent 0 talking to agent 2
# Speaker loss: 0.00, receiver loss: -0.31
# tensor([2, 5, 7, 1, 4]) tensor([9, 9, 9, 9, 9]) tensor([1, 1, 1, 1, 1])
# Epoch 440000, agent 0 talking to agent 0
# Speaker loss: 0.00, receiver loss: -0.12
# tensor([6, 9, 4, 8, 9]) tensor([9, 9, 9, 9, 9]) tensor([7, 7, 7, 7, 7])
# Epoch 450000, agent 1 talking to agent 1
# Speaker loss: 0.00, receiver loss: -0.12
# tensor([8, 9, 3, 6, 8]) tensor([0, 2, 0, 7, 0]) tensor([1, 6, 1, 8, 1])
# Epoch 460000, agent 0 talking to agent 0
# Speaker loss: 0.00, receiver loss: -0.25
# tensor([1, 9, 9, 8, 7]) tensor([9, 9, 9, 9, 9]) tensor([7, 7, 7, 7, 7])
# Epoch 470000, agent 1 talking to agent 0
# Speaker loss: 0.00, receiver loss: -0.19
# tensor([5, 8, 0, 7, 7]) tensor([2, 0, 0, 0, 0]) tensor([2, 1, 1, 1, 1])
# Epoch 480000, agent 2 talking to agent 2
# Speaker loss: 0.00, receiver loss: -0.50
# tensor([9, 7, 6, 1, 3]) tensor([2, 2, 2, 0, 4]) tensor([2, 2, 2, 1, 3])
# Epoch 490000, agent 1 talking to agent 1
# Speaker loss: -0.00, receiver loss: -0.00
# tensor([8, 2, 6, 7, 3]) tensor([0, 2, 7, 0, 0]) tensor([1, 6, 8, 1, 1])
# Epoch 500000, agent 2 talking to agent 0
# Speaker loss: 0.00, receiver loss: -0.62
# tensor([9, 9, 6, 3, 2]) tensor([2, 2, 2, 4, 2]) tensor([2, 2, 2, 3, 2])
# Epoch 510000, agent 0 talking to agent 1
# Speaker loss: 0.00, receiver loss: -0.31
# tensor([4, 3, 0, 9, 8]) tensor([9, 4, 9, 9, 9]) tensor([1, 3, 1, 1, 1])
# Epoch 520000, agent 1 talking to agent 2
# Speaker loss: 0.00, receiver loss: -0.06
# tensor([3, 3, 5, 8, 1]) tensor([0, 0, 2, 0, 0]) tensor([1, 1, 2, 1, 1])
# Epoch 530000, agent 0 talking to agent 0
# Speaker loss: 0.00, receiver loss: -0.31
# tensor([4, 3, 3, 2, 1]) tensor([9, 4, 4, 9, 9]) tensor([7, 3, 3, 7, 7])
# Epoch 540000, agent 1 talking to agent 0
# Speaker loss: 0.00, receiver loss: -0.31
# tensor([4, 7, 3, 8, 1]) tensor([2, 0, 0, 0, 0]) tensor([2, 1, 1, 1, 1])
# Epoch 550000, agent 1 talking to agent 1
# Speaker loss: 0.00, receiver loss: -0.00
# tensor([4, 7, 8, 0, 3]) tensor([2, 0, 0, 0, 0]) tensor([6, 1, 1, 1, 1])
# Epoch 560000, agent 0 talking to agent 0
# Speaker loss: 0.00, receiver loss: -0.19
# tensor([7, 6, 0, 4, 0]) tensor([9, 9, 9, 9, 9]) tensor([7, 7, 7, 7, 7])
# Epoch 570000, agent 0 talking to agent 0
# Speaker loss: 0.00, receiver loss: -0.25
# tensor([6, 4, 4, 5, 6]) tensor([9, 9, 9, 9, 9]) tensor([7, 7, 7, 7, 7])
# Epoch 580000, agent 1 talking to agent 2
# Speaker loss: 0.00, receiver loss: -0.31
# tensor([2, 5, 3, 2, 4]) tensor([2, 2, 0, 2, 2]) tensor([2, 2, 1, 2, 2])
# Epoch 590000, agent 2 talking to agent 2
# Speaker loss: 0.00, receiver loss: -0.44
# tensor([3, 6, 8, 6, 4]) tensor([4, 2, 6, 2, 0]) tensor([3, 2, 9, 2, 1])
# Epoch 600000, agent 1 talking to agent 0
# Speaker loss: 0.00, receiver loss: -0.31
# tensor([5, 9, 1, 4, 6]) tensor([2, 2, 0, 2, 7]) tensor([2, 2, 1, 2, 6])
# Epoch 610000, agent 2 talking to agent 2
# Speaker loss: 0.00, receiver loss: -0.44
# tensor([4, 6, 2, 3, 1]) tensor([0, 2, 2, 4, 0]) tensor([1, 2, 2, 3, 1])
# Epoch 620000, agent 0 talking to agent 1
# Speaker loss: 0.00, receiver loss: -0.19
# tensor([7, 1, 8, 2, 5]) tensor([9, 9, 9, 9, 9]) tensor([1, 1, 1, 1, 1])
# Epoch 630000, agent 1 talking to agent 2
# Speaker loss: 0.00, receiver loss: -0.12
# tensor([9, 3, 5, 9, 5]) tensor([2, 0, 2, 2, 2]) tensor([2, 1, 2, 2, 2])
# Epoch 640000, agent 0 talking to agent 0
# Speaker loss: 0.00, receiver loss: -0.12
# tensor([6, 1, 0, 6, 0]) tensor([9, 9, 9, 9, 9]) tensor([7, 7, 7, 7, 7])
# Epoch 650000, agent 2 talking to agent 1
# Speaker loss: 0.00, receiver loss: -0.62
# tensor([1, 4, 6, 7, 5]) tensor([0, 0, 2, 2, 8]) tensor([1, 1, 6, 6, 5])
# Epoch 660000, agent 0 talking to agent 1
# Speaker loss: 0.00, receiver loss: -0.19
# tensor([6, 9, 8, 7, 8]) tensor([9, 9, 9, 9, 9]) tensor([1, 1, 1, 1, 1])
# Epoch 670000, agent 0 talking to agent 0
# Speaker loss: 0.00, receiver loss: -0.12
# tensor([6, 6, 3, 4, 6]) tensor([9, 9, 4, 9, 9]) tensor([7, 7, 3, 7, 7])
# Epoch 680000, agent 1 talking to agent 0
# Speaker loss: 0.00, receiver loss: -0.38
# tensor([7, 6, 0, 8, 9]) tensor([0, 7, 0, 0, 2]) tensor([1, 6, 1, 1, 2])
# Epoch 690000, agent 0 talking to agent 2
# Speaker loss: 0.00, receiver loss: -0.38
# tensor([4, 6, 4, 5, 9]) tensor([9, 9, 9, 9, 9]) tensor([1, 1, 1, 1, 1])
# Epoch 700000, agent 2 talking to agent 1
# Speaker loss: 0.00, receiver loss: -0.62
# tensor([6, 5, 7, 3, 3]) tensor([2, 8, 2, 4, 4]) tensor([6, 5, 6, 3, 3])
# Epoch 710000, agent 0 talking to agent 1
# Speaker loss: 0.00, receiver loss: -0.06
# tensor([6, 6, 6, 4, 8]) tensor([9, 9, 9, 9, 9]) tensor([1, 1, 1, 1, 1])
# Epoch 720000, agent 1 talking to agent 0
# Speaker loss: 0.00, receiver loss: -0.38
# tensor([4, 1, 7, 1, 5]) tensor([2, 0, 0, 0, 2]) tensor([2, 1, 1, 1, 2])
# Epoch 730000, agent 0 talking to agent 2
# Speaker loss: 0.00, receiver loss: -0.06
# tensor([8, 9, 1, 7, 8]) tensor([9, 9, 9, 9, 9]) tensor([1, 1, 1, 1, 1])
# Epoch 740000, agent 2 talking to agent 0
# Speaker loss: 0.00, receiver loss: -0.62
# tensor([1, 5, 6, 1, 5]) tensor([0, 8, 2, 0, 8]) tensor([1, 5, 2, 1, 5])
# Epoch 750000, agent 0 talking to agent 0
# Speaker loss: 0.00, receiver loss: -0.19
# tensor([0, 9, 3, 7, 4]) tensor([9, 9, 4, 9, 9]) tensor([7, 7, 3, 7, 7])
# Epoch 760000, agent 2 talking to agent 1
# Speaker loss: 0.00, receiver loss: -0.50
# tensor([6, 8, 0, 1, 0]) tensor([2, 6, 2, 0, 2]) tensor([6, 8, 6, 1, 6])
# Epoch 770000, agent 0 talking to agent 2
# Speaker loss: 0.00, receiver loss: -0.06
# tensor([9, 0, 2, 4, 8]) tensor([9, 9, 9, 9, 9]) tensor([1, 1, 1, 1, 1])
# Epoch 780000, agent 1 talking to agent 2
# Speaker loss: -0.00, receiver loss: -0.00
# tensor([8, 6, 8, 6, 8]) tensor([0, 7, 0, 7, 0]) tensor([1, 8, 1, 8, 1])
# Epoch 790000, agent 2 talking to agent 1
# Speaker loss: 0.00, receiver loss: -0.56
# tensor([1, 8, 2, 0, 9]) tensor([0, 6, 2, 2, 2]) tensor([1, 8, 6, 6, 6])
# Epoch 800000, agent 0 talking to agent 0
# Speaker loss: 0.00, receiver loss: -0.25
# tensor([3, 6, 7, 4, 8]) tensor([4, 9, 9, 9, 9]) tensor([3, 7, 7, 7, 7])
# Epoch 810000, agent 1 talking to agent 0
# Speaker loss: 0.00, receiver loss: -0.38
# tensor([2, 5, 8, 1, 0]) tensor([2, 2, 0, 0, 0]) tensor([2, 2, 1, 1, 1])
# Epoch 820000, agent 1 talking to agent 0
# Speaker loss: 0.00, receiver loss: -0.38
# tensor([0, 6, 5, 5, 1]) tensor([0, 7, 2, 2, 0]) tensor([1, 6, 2, 2, 1])
# Epoch 830000, agent 1 talking to agent 2
# Speaker loss: 0.00, receiver loss: -0.12
# tensor([8, 5, 8, 6, 6]) tensor([0, 2, 0, 7, 7]) tensor([1, 2, 1, 8, 8])
# Epoch 840000, agent 0 talking to agent 2
# Speaker loss: 0.00, receiver loss: -0.06
# tensor([3, 4, 8, 0, 9]) tensor([4, 9, 9, 9, 9]) tensor([3, 1, 1, 1, 1])
# Epoch 850000, agent 2 talking to agent 2
# Speaker loss: 0.00, receiver loss: -0.50
# tensor([6, 5, 3, 1, 4]) tensor([2, 8, 4, 0, 0]) tensor([2, 5, 3, 1, 1])
# Epoch 860000, agent 2 talking to agent 0
# Speaker loss: 0.00, receiver loss: -0.69
# tensor([4, 9, 5, 1, 7]) tensor([0, 2, 8, 0, 2]) tensor([1, 2, 5, 1, 2])
# Epoch 870000, agent 2 talking to agent 2
# Speaker loss: 0.00, receiver loss: -0.44
# tensor([3, 1, 4, 6, 4]) tensor([4, 0, 0, 2, 0]) tensor([3, 1, 1, 2, 1])
# Epoch 880000, agent 0 talking to agent 0
# Speaker loss: 0.00, receiver loss: -0.06
# tensor([1, 8, 6, 4, 4]) tensor([9, 9, 9, 9, 9]) tensor([7, 7, 7, 7, 7])
# Epoch 890000, agent 2 talking to agent 1
# Speaker loss: 0.00, receiver loss: -0.44
# tensor([0, 2, 7, 8, 4]) tensor([2, 2, 2, 6, 0]) tensor([6, 6, 6, 8, 1])
# Epoch 900000, agent 1 talking to agent 2
# Speaker loss: 0.00, receiver loss: -0.06
# tensor([9, 6, 8, 3, 6]) tensor([2, 7, 0, 0, 7]) tensor([2, 8, 1, 1, 8])
# Epoch 910000, agent 2 talking to agent 0
# Speaker loss: 0.00, receiver loss: -0.44
# tensor([4, 4, 2, 9, 2]) tensor([0, 0, 2, 2, 2]) tensor([1, 1, 2, 2, 2])
# Epoch 920000, agent 0 talking to agent 0
# Speaker loss: 0.00, receiver loss: -0.06
# tensor([6, 1, 0, 4, 8]) tensor([9, 9, 9, 9, 9]) tensor([7, 7, 7, 7, 7])
# Epoch 930000, agent 0 talking to agent 2
# Speaker loss: 0.00, receiver loss: -0.12
# tensor([4, 2, 8, 5, 7]) tensor([9, 9, 9, 9, 9]) tensor([1, 1, 1, 1, 1])
# Epoch 940000, agent 1 talking to agent 0
# Speaker loss: 0.00, receiver loss: -0.31
# tensor([8, 0, 4, 6, 5]) tensor([0, 0, 2, 7, 2]) tensor([1, 1, 2, 6, 2])
# Epoch 950000, agent 2 talking to agent 0
# Speaker loss: 0.00, receiver loss: -0.56
# tensor([3, 8, 1, 0, 2]) tensor([4, 6, 0, 2, 2]) tensor([3, 8, 1, 2, 2])
# Epoch 960000, agent 0 talking to agent 2
# Speaker loss: 0.00, receiver loss: -0.12
# tensor([8, 4, 6, 3, 4]) tensor([9, 9, 9, 4, 9]) tensor([1, 1, 1, 3, 1])
# Epoch 970000, agent 1 talking to agent 2
# Speaker loss: 0.00, receiver loss: -0.25
# tensor([5, 9, 8, 0, 9]) tensor([2, 2, 0, 0, 2]) tensor([2, 2, 1, 1, 2])
# Epoch 980000, agent 1 talking to agent 2
# Speaker loss: 0.00, receiver loss: -0.06
# tensor([0, 7, 1, 5, 4]) tensor([0, 0, 0, 2, 2]) tensor([1, 1, 1, 2, 2])
# Epoch 990000, agent 1 talking to agent 2
# Speaker loss: 0.00, receiver loss: -0.31
# tensor([1, 8, 1, 4, 4]) tensor([0, 0, 0, 2, 2]) tensor([1, 1, 1, 2, 2])

# %%
train(1)
# Out:
# Epoch 0, agent 0 talking to agent 0
# Speaker loss: -0.00, receiver loss: -0.11
# tensor([7, 4, 2, 6, 0]) tensor([ 8, 14,  8, 12, 14]) tensor([2, 1, 2, 5, 1])
# Epoch 10000, agent 0 talking to agent 0
# Speaker loss: 0.00, receiver loss: -0.56
# tensor
, agent 0 talking to agent 0
# Speaker loss: 0.00, receiver loss: -0.31
# tensor([5, 8, 5, 6, 6]) tensor([7, 7, 7, 7, 7]) tensor([8, 8, 8, 8, 8])
# Epoch 770000, agent 0 talking to agent 0
# Speaker loss: 0.00, receiver loss: -0.31
# tensor([3, 3, 3, 9, 5]) tensor([7, 7, 7, 1, 7]) tensor([8, 8, 8, 9, 8])
# Epoch 780000, agent 0 talking to agent 0
# Speaker loss: 0.00, receiver loss: -0.56
# tensor([3, 3, 9, 3, 2]) tensor([7, 7, 1, 7, 7]) tensor([8, 8, 9, 8, 8])
# Epoch 790000, agent 0 talking to agent 0
# Speaker loss: 0.00, receiver loss: -0.31
# tensor([8, 2, 4, 2, 7]) tensor([7, 7, 1, 7, 8]) tensor([8, 8, 9, 8, 7])
# Epoch 800000, agent 0 talking to agent 0
# Speaker loss: 0.00, receiver loss: -0.62
# tensor([8, 5, 4, 1, 4]) tensor([7, 7, 1, 7, 1]) tensor([8, 8, 9, 8, 9])
# Epoch 810000, agent 0 talking to agent 0
# Speaker loss: 0.00, receiver loss: -0.44
# tensor([0, 5, 5, 7, 2]) tensor([9, 7, 7, 8, 7]) tensor([0, 8, 8, 7, 8])
# Epoch 820000, agent 0 talking to agent 0
# Speaker loss: 0.00, receiver loss: -0.19
# tensor([2, 3, 5, 2, 7]) tensor([7, 7, 7, 7, 8]) tensor([8, 8, 8, 8, 7])
# Epoch 830000, agent 0 talking to agent 0
# Speaker loss: 0.00, receiver loss: -0.19
# tensor([9, 6, 3, 6, 1]) tensor([1, 7, 7, 7, 7]) tensor([9, 8, 8, 8, 8])
# Epoch 840000, agent 0 talking to agent 0
# Speaker loss: 0.00, receiver loss: -0.38
# tensor([7, 3, 3, 1, 3]) tensor([8, 7, 7, 7, 7]) tensor([7, 8, 8, 8, 8])
# Epoch 850000, agent 0 talking to agent 0
# Speaker loss: 0.00, receiver loss: -0.56
# tensor([6, 8, 8, 3, 6]) tensor([7, 7, 7, 7, 7]) tensor([8, 8, 8, 8, 8])
# Epoch 860000, agent 0 talking to agent 0
# Speaker loss: 0.00, receiver loss: -0.44
# tensor([6, 9, 7, 2, 6]) tensor([7, 1, 8, 7, 7]) tensor([8, 9, 7, 8, 8])
# Epoch 870000, agent 0 talking to agent 0
# Speaker loss: 0.00, receiver loss: -0.44
# tensor([2, 9, 7, 1, 2]) tensor([7, 1, 8, 7, 7]) tensor([8, 9, 7, 8, 8])
# Epoch 880000, agent 0 talking to agent 0
# Speaker loss: 0.00, receiver loss: -0.69
# tensor([4, 6, 9, 2, 7]) tensor([1, 7, 1, 7, 8]) tensor([9, 8, 9, 8, 7])
# Epoch 890000, agent 0 talking to agent 0
# Speaker loss: 0.00, receiver loss: -0.31
# tensor([3, 6, 0, 4, 1]) tensor([7, 7, 9, 1, 7]) tensor([8, 8, 0, 9, 8])
# Epoch 900000, agent 0 talking to agent 0
# Speaker loss: 0.00, receiver loss: -0.31
# tensor([6, 8, 2, 5, 4]) tensor([7, 7, 7, 7, 1]) tensor([8, 8, 8, 8, 9])
# Epoch 910000, agent 0 talking to agent 0
# Speaker loss: 0.00, receiver loss: -0.56
# tensor([5, 9, 5, 9, 1]) tensor([7, 1, 7, 1, 7]) tensor([8, 9, 8, 9, 8])
# Epoch 920000, agent 0 talking to agent 0
# Speaker loss: 0.00, receiver loss: -0.56
# tensor([0, 1, 1, 9, 8]) tensor([9, 7, 7, 1, 7]) tensor([0, 8, 8, 9, 8])
# Epoch 930000, agent 0 talking to agent 0
# Speaker loss: 0.00, receiver loss: -0.25
# tensor([2, 2, 5, 5, 3]) tensor([7, 7, 7, 7, 7]) tensor([8, 8, 8, 8, 8])
# Epoch 940000, agent 0 talking to agent 0
# Speaker loss: 0.00, receiver loss: -0.62
# tensor([1, 2, 5, 5, 8]) tensor([7, 7, 7, 7, 7]) tensor([8, 8, 8, 8, 8])
# Epoch 950000, agent 0 talking to agent 0
# Speaker loss: 0.00, receiver loss: -0.31
# tensor([3, 7, 6, 0, 9]) tensor([7, 8, 7, 9, 1]) tensor([8, 7, 8, 0, 9])
# Epoch 960000, agent 0 talking to agent 0
# Speaker loss: 0.00, receiver loss: -0.44
# tensor([6, 6, 5, 5, 4]) tensor([7, 7, 7, 7, 1]) tensor([8, 8, 8, 8, 9])
# Epoch 970000, agent 0 talking to agent 0
# Speaker loss: 0.00, receiver loss: -0.56
# tensor([3, 8, 0, 5, 1]) tensor([7, 7, 9, 7, 7]) tensor([8, 8, 0, 8, 8])
# Epoch 980000, agent 0 talking to agent 0
# Speaker loss: 0.00, receiver loss: -0.31
# tensor([8, 1, 9, 4, 5]) tensor([7, 7, 1, 1, 7]) tensor([8, 8, 9, 9, 8])
# Epoch 990000, agent 0 talking to agent 0
# Speaker loss: 0.00, receiver loss: -0.31
# tensor([4, 5, 4, 0, 0]) tensor([1, 7, 1, 9, 9]) tensor([9, 8, 9, 0, 0])
